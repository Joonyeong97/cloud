# %% [markdown]
# <a href="https://colab.research.google.com/github/yeongtaeck97s/cloud/blob/master/Twitter_crol_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install customized_konlpy
# test

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm
import pandas as pd
import re

result = []


def scroll(q):
    body = driver.find_element_by_css_selector('body')
    for i in range(q):
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)

def croll():
    for ttt in tqdm(text2):
        result.append(ttt.text)
        
# 코로나 바이러스
keyword = "코로나"

# 웹접속 - 네이버 이미지 접속
# 79.0.3945.36 / chrome version
print("접속중")
driver = webdriver.Chrome(executable_path="./chromedriver.exe")
driver.implicitly_wait(30)

url = 'https://twitter.com/search?q={}&src=typed_query&f=live'.format(keyword)
driver.get(url)
time.sleep(3)
driver.find_elements_by_css_selector('#react-root > div > div > div > main > div > div > div > div > div > div:nth-child(2) > div')


for i in range(30):
    scroll(3)
    croll()
    time.sleep(1)

driver.close()



#     aa = []
#     for q,i in enumerate(result2):
#         aa.append(int(cleanText(i)))
#     result2 = aa



# print('수집완료')


# text2 = driver.find_elements_by_css_selector('span.css-901oao.css-16my406.r-1qd0xha.r-ad9z0x.r-bcqeeo.r-qvutc0')
# text2 = driver.find_elements_by_css_selector('div.css-1dbjc4n')
# Out:
# 접속중
#   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-22d159dca81f> in <module>
#      36 for i in range(30):
#      37     scroll(3)
# ---> 38     croll()
#      39     time.sleep(1)
#      40
#
# <ipython-input-14-22d159dca81f> in croll()
#      17 def croll():
#      18     for ttt in tqdm(text2):
# ---> 19         result.append(ttt.text)
#      20
#      21 # 코로나 바이러스
#
# ~\Anaconda3\envs\Testing\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~\Anaconda3\envs\Testing\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
# ...

# %%
len(result)
# Out:
# 60

# %%
def cleanText(readData):
    # 텍스트에 포함되어 있는 특수 문자 제거
    text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》\n_·李永钦타임라인레]', '', readData)
    return text

# %%
result2 = []
for i in range(len(result)):
    if i % 2 == 0:
        result2.append(result[i])
print(len(result2))
# Out:
# 30

# %%
result3 = []
for i in range(len(result2)):
    result3.append(cleanText(result2[i]))

# %%
import ckonlpy
from ckonlpy.tag import Twitter
ckonlpy.__version__
# Out:
# '0.0.64'

# %%
from ckonlpy.tag import Twitter
t = Twitter()
t.add_dictionary(['트와이스', 'kf94','KF94','Kf94','kF94','타임라인','확진자','예방수칙','코로나19','corona19','Corona19',
                 '개소리','판매','제품','쿠팡','kf94마스크','KF94마스크','Kf94마스크','kF94마스크','내고'
                 '우한폐렴','신종코로나','신종코로나바이러스','coronavirus','Coronavirus','사재기','박나래'
                 '복지부장관', '바이러스', '피해복구', '이만희', '문재인', '이재갑','한림대', '백만원','100만원','이성훈'
                 '감염내과', '교수님', '정치인','뮤직뱅크','bts','방탄소년단','방탄'], 'Noun')
# Out:
# C:\Users\82105\Anaconda3\envs\Testing\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
result3[1]
# Out:
# ' 검색맨듀zeungjeonsu2월 2일휴일 지킴이 약국 찾기Else one of the poppiesElse681315971월 27일rogerS2car 님에게 보내는 답글샘 휴일지킴이약국 검색해보시면 휴일에 여는 약국 찾아볼 수 있어요1김다홍transparentpig1월 27일8HK7E 님에게 보내는 답글휴일지킴이약국’이고 검색하시면 오늘 문 여는 약국이 어딘지 확하실 수 있어요 다만  일회용 미세먼지마스크 방역마스크가 아닌 방독면같이 생긴 마스크’도 팔지는 의문이네요 그래도 약국에 전화해서 확해보실 수는 있을 듯해요1안양시anyanglove1월 24일연휴기간에 아픈 가족이 있다면안양시 설 연휴기간 비상 진료 기관과휴일 지킴이 약국아래 링크에서 확해주시기 바랍니다건강하고 행복한 설 보내세요비상 진료 기관휴일 지킴이 약국정보 보러 가기  httpsc11krcuvi2유지호youziho841월 24일첫 명절 기념으로 셋이서 한복 입고 예쁜 사진 찍기로 했거든요 물론 동네 어르신들께 세배도 가야겠죠은우는 세뱃돈 받을 생각에 들떠있어요 받으면 꼬깃꼬깃 모으기만 하는 자린고비면서아 저는 내일 휴일지킴이약국 당첨이 일해요 흠말하다 보니 별로 한가한 명절은 아니네웃음1215이 스드 보기BreakNewsBreakNewsCom1월 23일경주시 설 명절 비상진료의료기관휴일지킴이 약국 운영  브이크뉴스브이크뉴스【브이크뉴스 경주】김가이 기자 경주시는 설 명절 연휴기간 진료공백에 따른 비상응급의료대책을 마련해 시민 및 귀성객들이 즐거운 명절을 보낼 수 있도록 비상진료대책상황실과 비상진료의료기관 및 휴일지킴이breaknewscom서울시seoulmania1월 23일설날 연휴 문여는진료병원휴일지킴이약국 확httpblogseoulgokr221781228142문의 120 119감기약소화제 등 안전상비의약품은 편의점에서 구입 가능명절 준비장시간 운전 등으로 체력이 저하될 수 있으므로 충분한 휴식을 취하고 자주 손 씻기 등 감염병 예방수칙을 지켜주세요13636천광역시 계양구HappyGyeya
# ...

# %%
import nltk
from konlpy.tag import Twitter
import numpy as np
tokens_ko = []

for i in range(len(result3)):
    tokens_ko.append(t.nouns(result3[i]))

# %%
final = []
for _,q in enumerate(tokens_ko):
    for i in range(len(q)):
        final.insert(-1,q[i])

# %%
ko = nltk.Text(final, name="첫번째")
data = ko.vocab().most_common(1000)

# %%
import requests
from bs4 import BeautifulSoup
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
from konlpy.tag import Twitter
import numpy as np
from PIL import Image

tmp_data = dict(data)

wordcloud = WordCloud( font_path = '/Library/Fonts/NanumMyeongjo.ttf',
                       background_color='white').generate_from_frequencies(tmp_data)
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import nltk
from konlpy.tag import Twitter
import numpy as np
re3 = []


t = Twitter()
tokens_ko = t.nouns(result2[0])
tokens_ko2 = t.nouns(result2[1])
# ko = nltk.Text(tokens_ko, name="첫번째")
# ko.vocab().most_common(10)
# data = ko.vocab().most_common(1000)

# %%
for i in range(len(tokens_ko)):
    tokens_ko.insert(-1,tokens_ko2[i])

# %%
ko = nltk.Text(tokens_ko, name="첫번째")
ko.vocab().most_common(10)
data = ko.vocab().most_common(1000)

# %%
data
# Out:
# [('폐렴', 56),
#  ('우한', 52),
#  ('코로나', 26),
#  ('대표', 17),
#  ('확', 17),
#  ('진자', 17),
#  ('황교안', 14),
#  ('미로', 14),
#  ('혈세', 14),
#  ('말', 12),
#  ('대구', 12),
#  ('황', 10),
#  ('뉴스', 9),
#  ('붓기', 9),
#  ('지역', 8),
#  ('중국', 8),
#  ('성동구', 8),
#  ('사회', 7),
#  ('불안', 7),
#  ('고', 7),
#  ('오전', 7),
#  ('대응', 7),
#  ('하루', 7),
#  ('사람', 7),
#  ('발생', 7),
#  ('이', 6),
#  ('확산', 6),
#  ('주장', 6),
#  ('정부', 6),
#  ('비난', 6),
#  ('입국', 6),
#  ('계속', 6),
#  ('세', 6),
#  ('남성', 6),
#  ('감염', 6),
#  ('중국인', 6),
#  ('이데일리', 5),
#  ('장', 5),
#  ('영락', 5),
#  ('기자', 5),
#  ('시민', 5),
#  ('가운데', 5),
#  ('자유', 5),
#  ('한국', 5),
#  ('국회', 5),
#  ('최고', 5),
#  ('위원', 5),
#  ('회의', 5),
#  ('상황', 5),
#  ('어제', 5),
#  ('무려', 5),
#  ('여명', 5),
#  ('폭증', 5),
#  ('며', 5),
#  ('대구시', 5),
#  ('혐오', 5),
#  ('방역', 5),
#  ('금지', 5),
#  ('검색', 4),
#  ('신종', 4),
#  ('가짜', 4),
#  ('나라', 4),
#  ('먼저', 4),
#  ('권영진', 4),
#  ('사망자', 4),
#  ('일', 4),
#  ('책임', 4),
#  ('겨울', 4),
#  ('명', 4),
#  ('문재인', 4),
# ...

# %%
# 페이지 스크롤 다운
# body = driver.find_element_by_css_selector('body')
# for i in range(150):
#     body.send_keys(Keys.PAGE_DOWN)
#     time.sleep(1)

# # 이미지 링크 수집
# imgs = driver.find_elements_by_css_selector('img._img')
# result = []
# for img in tqdm(imgs):
#     if 'http' in img.get_attribute('src'):
#         result.append(img.get_attribute('src'))
# # print(result)
#
# driver.close()
# print('수집완료')
#
# # 파일 저장
# import os
# if not os.path.isdir('./{}'.format(key)):
#     print('폴더생성')
#     os.mkdir('./{}'.format(key))
#
# # 다운로드
# from urllib.request import urlretrieve
#
# print("다운로드중")
# for index, link in tqdm(enumerate(result)):
#     start = link.rfind('.')
#     end = link.rfind('&')
#     # print(link[start:end])
#     filetype = link[start:end]
#     if filetype == '.jpg':  # jpg 만 다운
#         urlretrieve(link, './{}/{}{}{}'.format(key, key, index, filetype))
#         time.sleep(1)
# print("다운로드 완료")
#
# # import zipfile
# # zip_file = zipfile.Zipfile('./{}.zip'.format(keyword),'w')
# # # 이 폴더안에 파일 가져오는거
# # for image in tqdm(os.listdir('./{}'.format(keyword))):
# #     zip_file.write('./{}/{}'.format(keyword,image), compress_type=zip_file.ZIP_DEFLATED)
# # zip_file.close()
# # print("압축완료")
